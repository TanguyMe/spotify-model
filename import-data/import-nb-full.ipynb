# %%
import os

import logging
import mysql.connector
import pandas as pd
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials
from datetime import datetime


logger = logging.getLogger()

# %%
years=range(1960,2023)
offsets=range(0,1000,50)

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

tracks_data_list = []

start = datetime.now()
print("start = ", start)
for year in years:
    for offset in offsets:
        try:
            track_results = spotify.search(q=f'year:{year}', type='track', limit=50, offset=offset)
            for track in track_results['tracks']['items']:
                single_track_dict = {                                       
                    'track_name': track['name'],
                    'artist_name': track['artists'][0]['name'],
                    'track_id': track['id'] ,
                    'popularity': track['popularity']
                }
                tracks_data_list.append(single_track_dict)
        except Exception as e:
            print(e)
            print(offset)
            logger.info(e)
            break
    print(f"Progression of years: {year}/{years[-1]}")
end = datetime.now()
print("finish = ", end)
print("duration = ", (end-start).total_seconds())
# Out:
# start =  2022-07-04 10:54:09.621154
# Progression of years: 1960/2022
# Progression of years: 1961/2022
# Progression of years: 1962/2022
# Progression of years: 1963/2022
# Progression of years: 1964/2022
# Progression of years: 1965/2022
# Progression of years: 1966/2022
# Progression of years: 1967/2022
# Progression of years: 1968/2022
# Progression of years: 1969/2022
# Progression of years: 1970/2022
# Progression of years: 1971/2022
# Progression of years: 1972/2022
# Progression of years: 1973/2022
# Progression of years: 1974/2022
# Progression of years: 1975/2022
# Progression of years: 1976/2022
# Progression of years: 1977/2022
# Progression of years: 1978/2022
# Progression of years: 1979/2022
# Progression of years: 1980/2022
# Progression of years: 1981/2022
# Progression of years: 1982/2022
# Progression of years: 1983/2022
# Progression of years: 1984/2022
# Progression of years: 1985/2022
# Progression of years: 1986/2022
# Progression of years: 1987/2022
# Progression of years: 1988/2022
# Progression of years: 1989/2022
# Progression of years: 1990/2022
# Progression of years: 1991/2022
# Progression of years: 1992/2022
# Progression of years: 1993/2022
# Progression of years: 1994/2022
# Progression of years: 1995/2022
# Progression of years: 1996/2022
# Progression of years: 1997/2022
# Progression of years: 1998/2022
# Progression of years: 1999/2022
# Progression of years: 2000/2022
# Progression of years: 2001/2022
# Progression of years: 2002/2022
# Progression of years: 2003/2022
# Progression of years: 2004/2022
# Progression of years: 2005/2022
# Progression of years: 2006/2022
# Progression of years: 2007/2022
# Progression of years: 2008/2022
# Progression of years: 2009/2022
# Progression of years: 2010/2022
# Progression of years: 2011/2022
# Progression of years: 2012/2022
# Progression of years: 2013/2022
# Progression of years: 2014/2022
# Progression of years: 2015/2022
# Progression of years: 2016/2022
# Progression of years: 2017/2022
# Progression of years: 2018/2022
# Progression of years: 2019/2022
# Progression of years: 2020/2022
# Progression of years: 2021/2022
# Progression of years: 2022/2022
# finish =  2022-07-04 11:04:15.543863
# duration =  605.922709

# %%
len(tracks_data_list)
# Out:
# 63000

# %%
df = pd.DataFrame(tracks_data_list)

# %% [markdown]
# Removing duplicates

# %%
df.duplicated().sum()
# Out:
# 1678

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (61322, 4)

# %%
def extract_audio_feature(ids_list):
    list_features = []
    try:
        list_features = spotify.audio_features(ids_list)
    except Exception as e:
        print(e)
        logger.info(e)
    return list_features

# %%
tracks_features_list = []

total_tracks = df.shape[0]

start = datetime.now()
print("start = ", start)
for tracks_nbr in range(0, total_tracks, 100):
    print(f"Progression of tracks: {tracks_nbr}/{total_tracks}")
    tracks_features_list += extract_audio_feature(','.join(df.track_id[tracks_nbr:tracks_nbr+100]))
remaining_tracks = total_tracks%100
if remaining_tracks:
    tracks_features_list += extract_audio_feature(','.join(df.track_id[-remaining_tracks:]))
end = datetime.now()
print("finish = ", end)
print("duration = ", (end-start).total_seconds())
# Out:
# start =  2022-07-04 11:13:38.014133
# Progression of tracks: 0/61322
# Progression of tracks: 100/61322
# Progression of tracks: 200/61322
# Progression of tracks: 300/61322
# Progression of tracks: 400/61322
# Progression of tracks: 500/61322
# Progression of tracks: 600/61322
# Progression of tracks: 700/61322
# Progression of tracks: 800/61322
# Progression of tracks: 900/61322
# Progression of tracks: 1000/61322
# Progression of tracks: 1100/61322
# Progression of tracks: 1200/61322
# Progression of tracks: 1300/61322
# Progression of tracks: 1400/61322
# Progression of tracks: 1500/61322
# Progression of tracks: 1600/61322
# Progression of tracks: 1700/61322
# Progression of tracks: 1800/61322
# Progression of tracks: 1900/61322
# Progression of tracks: 2000/61322
# Progression of tracks: 2100/61322
# Progression of tracks: 2200/61322
# Progression of tracks: 2300/61322
# Progression of tracks: 2400/61322
# Progression of tracks: 2500/61322
# Progression of tracks: 2600/61322
# Progression of tracks: 2700/61322
# Progression of tracks: 2800/61322
# Progression of tracks: 2900/61322
# Progression of tracks: 3000/61322
# Progression of tracks: 3100/61322
# Progression of tracks: 3200/61322
# Progression of tracks: 3300/61322
# Progression of tracks: 3400/61322
# Progression of tracks: 3500/61322
# Progression of tracks: 3600/61322
# Progression of tracks: 3700/61322
# Progression of tracks: 3800/61322
# Progression of tracks: 3900/61322
# Progression of tracks: 4000/61322
# Progression of tracks: 4100/61322
# Progression of tracks: 4200/61322
# Progression of tracks: 4300/61322
# Progression of tracks: 4400/61322
# Progression of tracks: 4500/61322
# Progression of tracks: 4600/61322
# Progression of tracks: 4700/61322
# Progression of tracks: 4800/61322
# Progression of tracks: 4900/61322
# Progression of tracks: 5000/61322
# Progression of tracks: 5100/61322
# Progression of tracks: 5200/61322
# Progression of tracks: 5300/61322
# Progression of tracks: 5400/61322
# Progression of tracks: 5500/61322
# Progression of tracks: 5600/61322
# Progression of tracks: 5700/61322
# Progression of tracks: 5800/61322
# Progression of tracks: 5900/61322
# Progression of tracks: 6000/61322
# Progression of tracks: 6100/61322
# Progression of tracks: 6200/61322
# Progression of tracks: 6300/61322
# Progression of tracks: 6400/61322
# Progression of tracks: 6500/61322
# Progression of tracks: 6600/61322
# Progression of tracks: 6700/61322
# Progression of tracks: 6800/61322
# Progression of tracks: 6900/61322
# Progression of tracks: 7000/61322
# Progression of tracks: 7100/61322
# Progression of tracks: 7200/61322
# Progression of tracks: 7300/61322
# Progression of tracks: 7400/61322
# Progression of tracks: 7500/61322
# Progression of tracks: 54700/61322
# Progression of tracks: 54800/61322
# Progression of tracks: 54900/61322
# Progression of tracks: 55000/61322
# Progression of tracks: 55100/61322
# Progression of tracks: 55200/61322
# Progression of tracks: 55300/61322
# Progression of tracks: 55400/61322
# Progression of tracks: 55500/61322
# Progression of tracks: 55600/61322
# Progression of tracks: 55700/61322
# Progression of tracks: 55800/61322
# Progression of tracks: 55900/61322
# Progression of tracks: 56000/61322
# Progression of tracks: 56100/61322
# Progression of tracks: 56200/61322
# Progression of tracks: 56300/61322
# Progression of tracks: 56400/61322
# Progression of tracks: 56500/61322
# Progression of tracks: 56600/61322
# Progression of tracks: 56700/61322
# Progression of tracks: 56800/61322
# Progression of tracks: 56900/61322
# Progression of tracks: 57000/61322
# Progression of tracks: 57100/61322
# Progression of tracks: 57200/61322
# Progression of tracks: 57300/61322
# Progression of tracks: 57400/61322
# Progression of tracks: 57500/61322
# Progression of tracks: 57600/61322
# Progression of tracks: 57700/61322
# Progression of tracks: 57800/61322
# Progression of tracks: 57900/61322
# Progression of tracks: 58000/61322
# Progression of tracks: 58100/61322
# Progression of tracks: 58200/61322
# Progression of tracks: 58300/61322
# Progression of tracks: 58400/61322
# Progression of tracks: 58500/61322
# Progression of tracks: 58600/61322
# Progression of tracks: 58700/61322
# Progression of tracks: 58800/61322
# Progression of tracks: 58900/61322
# Progression of tracks: 59000/61322
# Progression of tracks: 59100/61322
# Progression of tracks: 59200/61322
# Progression of tracks: 59300/61322
# Progression of tracks: 59400/61322
# Progression of tracks: 59500/61322
# Progression of tracks: 59600/61322
# Progression of tracks: 59700/61322
# Progression of tracks: 59800/61322
# Progression of tracks: 59900/61322
# Progression of tracks: 60000/61322
# Progression of tracks: 60100/61322
# Progression of tracks: 60200/61322
# Progression of tracks: 60300/61322
# Progression of tracks: 60400/61322
# Progression of tracks: 60500/61322
# Progression of tracks: 60600/61322
# Progression of tracks: 60700/61322
# Progression of tracks: 60800/61322
# Progression of tracks: 60900/61322
# Progression of tracks: 61000/61322
# Progression of tracks: 61100/61322
# Progression of tracks: 61200/61322
# Progression of tracks: 61300/61322
# finish =  2022-07-04 11:16:38.144300
# duration =  180.130167

# %% [markdown]
# For some songs, the audio feature is not done so we can remove this songs

# %%
len(tracks_features_list)
# Out:
# 61144

# %%
tracks_features_list = [track for track in tracks_features_list if isinstance(track, dict)]

# %%
len(tracks_features_list)
# Out:
# 61138

# %%
df2 = pd.DataFrame(tracks_features_list)

# %% [markdown]
# Need to clean the duplicate again, it seems that the API requests are doubled sometimes.

# %%
df2.shape
# Out:
# (61138, 18)

# %%
df2.duplicated().sum()
df2.drop_duplicates(inplace=True)
df2.shape
# Out:
# (61116, 18)

# %%
final_df = df.set_index('track_id').join(df2.set_index('id'), how='inner')

# %%
final_df.shape
# Out:
# (61116, 20)

# %%
final_df.sample(10)
# Out:
#                                                                track_name  \
# 5gb9UJkh8TfrNMRYOJNbew                                     Gives You Hell
# 0UgHkodbptL6XQBfT5HOK1                                        You Save Me
# 5LDZbklcDwQeeScf7dUlo4                                    Big City Nights
# 591vJuuep0gfPhx9p8WPD5                              Reinventing Your Exit
# 4xqMJ1jBi557DT0LETsKGp                                 Tears On My Pillow
# 4J9rPbFgjPVgtarnfIULsq                              He Nacido para Amarte
# 7pzmpzvdtgIFKQz2vHbkOp  You Should Be Dancing - Edit / From "Saturday ...
# 5NbH5YGvgF2RbrxeXnGVkM                    There Will Never Be Another You
# 56uiDIiXz2sRoQ0AXq84aI                                     Metal On Metal
# 4Vb5Y6RQztThqqqFre24wL                                             Omerta
#
#                                      artist_name  popularity  danceability  \
# 5gb9UJkh8TfrNMRYOJNbew  The All-American Rejects          70         0.718
# 0UgHkodbptL6XQBfT5HOK1             Kenny Chesney          53         0.509
# 5LDZbklcDwQeeScf7dUlo4                 Scorpions          56         0.532
# 591vJuuep0gfPhx9p8WPD5                 Underoath          57         0.450
# 4xqMJ1jBi557DT0LETsKGp               New Edition          33         0.488
# 4J9rPbFgjPVgtarnfIULsq             Los Warahuaco          37         0.629
# 7pzmpzvdtgIFKQz2vHbkOp                  Bee Gees          41         0.677
# 5NbH5YGvgF2RbrxeXnGVkM              Chris Montez          35         0.731
# 56uiDIiXz2sRoQ0AXq84aI                     Anvil          47         0.459
# 4Vb5Y6RQztThqqqFre24wL               Lamb of God          59         0.413
#
#                         energy  key  loudness  mode  speechiness  \
# 5gb9UJkh8TfrNMRYOJNbew   0.691    4    -6.440     1       0.0387
# 0UgHkodbptL6XQBfT5HOK1   0.547    0    -6.132     1       0.0299
# 5LDZbklcDwQeeScf7dUlo4   0.723    9   -11.779     0       0.0333
# 591vJuuep0gfPhx9p8WPD5   0.978    9    -4.198     0       0.0637
# 4xqMJ1jBi557DT0LETsKGp   0.330    4   -15.581     0       0.0332
# 4J9rPbFgjPVgtarnfIULsq   0.495   10    -9.018     0       0.0555
# 7pzmpzvdtgIFKQz2vHbkOp   0.692    0   -13.033     1       0.0465
# 5NbH5YGvgF2RbrxeXnGVkM   0.379    7   -11.724     1       0.0387
# 56uiDIiXz2sRoQ0AXq84aI   0.923   10    -6.081     0       0.0709
# 4Vb5Y6RQztThqqqFre24wL   0.982    6    -4.079     0       0.2010
#
#                         acousticness  instrumentalness  liveness  valence  \
# 5gb9UJkh8TfrNMRYOJNbew      0.015900          0.000000    0.0627    0.552
# 0UgHkodbptL6XQBfT5HOK1      0.330000          0.000095    0.3580    0.282
# 5LDZbklcDwQeeScf7dUlo4      0.001520          0.004250    0.0780    0.866
# 591vJuuep0gfPhx9p8WPD5      0.000124          0.000007    0.3610    0.268
# 4xqMJ1jBi557DT0LETsKGp      0.194000          0.000015    0.1650    0.560
# 4J9rPbFgjPVgtarnfIULsq      0.343000          0.000000    0.0856    0.963
# 7pzmpzvdtgIFKQz2vHbkOp      0.019200          0.128000    0.1320    0.956
# 5NbH5YGvgF2RbrxeXnGVkM      0.628000          0.000000    0.1070    0.793
# 56uiDIiXz2sRoQ0AXq84aI      0.000092          0.000001    0.4540    0.548
# 4Vb5Y6RQztThqqqFre24wL      0.002420          0.001120    0.3230    0.155
#
#                           tempo            type  \
# 5gb9UJkh8TfrNMRYOJNbew  100.008  audio_features
# 0UgHkodbptL6XQBfT5HOK1  125.889  audio_features
# 5LDZbklcDwQeeScf7dUlo4  137.662  audio_features
# 591vJuuep0gfPhx9p8WPD5  155.014  audio_features
# 4xqMJ1jBi557DT0LETsKGp  102.693  audio_features
# 4J9rPbFgjPVgtarnfIULsq  178.610  audio_features
# 7pzmpzvdtgIFKQz2vHbkOp  123.381  audio_features
# 5NbH5YGvgF2RbrxeXnGVkM  127.513  audio_features
# 56uiDIiXz2sRoQ0AXq84aI  119.838  audio_features
# 4Vb5Y6RQztThqqqFre24wL  118.504  audio_features
#
#                                                          uri  \
# 5gb9UJkh8TfrNMRYOJNbew  spotify:track:5gb9UJkh8TfrNMRYOJNbew
# 0UgHkodbptL6XQBfT5HOK1  spotify:track:0UgHkodbptL6XQBfT5HOK1
# 5LDZbklcDwQeeScf7dUlo4  spotify:track:5LDZbklcDwQeeScf7dUlo4
# 591vJuuep0gfPhx9p8WPD5  spotify:track:591vJuuep0gfPhx9p8WPD5
# 4xqMJ1jBi557DT0LETsKGp  spotify:track:4xqMJ1jBi557DT0LETsKGp
# 4J9rPbFgjPVgtarnfIULsq  spotify:track:4J9rPbFgjPVgtarnfIULsq
# 7pzmpzvdtgIFKQz2vHbkOp  spotify:track:7pzmpzvdtgIFKQz2vHbkOp
# 5NbH5YGvgF2RbrxeXnGVkM  spotify:track:5NbH5YGvgF2RbrxeXnGVkM
# 56uiDIiXz2sRoQ0AXq84aI  spotify:track:56uiDIiXz2sRoQ0AXq84aI
# 4Vb5Y6RQztThqqqFre24wL  spotify:track:4Vb5Y6RQztThqqqFre24wL
#
#                                                                track_href  \
# 5gb9UJkh8TfrNMRYOJNbew  https://api.spotify.com/v1/tracks/5gb9UJkh8Tfr...
# 0UgHkodbptL6XQBfT5HOK1  https://api.spotify.com/v1/tracks/0UgHkodbptL6...
# 5LDZbklcDwQeeScf7dUlo4  https://api.spotify.com/v1/tracks/5LDZbklcDwQe...
# 591vJuuep0gfPhx9p8WPD5  https://api.spotify.com/v1/tracks/591vJuuep0gf...
# 4xqMJ1jBi557DT0LETsKGp  https://api.spotify.com/v1/tracks/4xqMJ1jBi557...
# 4J9rPbFgjPVgtarnfIULsq  https://api.spotify.com/v1/tracks/4J9rPbFgjPVg...
# 7pzmpzvdtgIFKQz2vHbkOp  https://api.spotify.com/v1/tracks/7pzmpzvdtgIF...
# 5NbH5YGvgF2RbrxeXnGVkM  https://api.spotify.com/v1/tracks/5NbH5YGvgF2R...
# 56uiDIiXz2sRoQ0AXq84aI  https://api.spotify.com/v1/tracks/56uiDIiXz2sR...
# 4Vb5Y6RQztThqqqFre24wL  https://api.spotify.com/v1/tracks/4Vb5Y6RQztTh...
#
#                                                              analysis_url  \
# 5gb9UJkh8TfrNMRYOJNbew  https://api.spotify.com/v1/audio-analysis/5gb9...
# 0UgHkodbptL6XQBfT5HOK1  https://api.spotify.com/v1/audio-analysis/0UgH...
# 5LDZbklcDwQeeScf7dUlo4  https://api.spotify.com/v1/audio-analysis/5LDZ...
# 591vJuuep0gfPhx9p8WPD5  https://api.spotify.com/v1/audio-analysis/591v...
# 4xqMJ1jBi557DT0LETsKGp  https://api.spotify.com/v1/audio-analysis/4xqM...
# 4J9rPbFgjPVgtarnfIULsq  https://api.spotify.com/v1/audio-analysis/4J9r...
# 7pzmpzvdtgIFKQz2vHbkOp  https://api.spotify.com/v1/audio-analysis/7pzm...
# 5NbH5YGvgF2RbrxeXnGVkM  https://api.spotify.com/v1/audio-analysis/5NbH...
# 56uiDIiXz2sRoQ0AXq84aI  https://api.spotify.com/v1/audio-analysis/56ui...
# 4Vb5Y6RQztThqqqFre24wL  https://api.spotify.com/v1/audio-analysis/4Vb5...
#
#                         duration_ms  time_signature
# 5gb9UJkh8TfrNMRYOJNbew       213107               4
# 0UgHkodbptL6XQBfT5HOK1       235773               3
# 5LDZbklcDwQeeScf7dUlo4       249307               4
# 591vJuuep0gfPhx9p8WPD5       262573               4
# 4xqMJ1jBi557DT0LETsKGp       236307               3
# 4J9rPbFgjPVgtarnfIULsq       190147               4
# 7pzmpzvdtgIFKQz2vHbkOp       253867               4
# 5NbH5YGvgF2RbrxeXnGVkM       175507               4
# 56uiDIiXz2sRoQ0AXq84aI       236360               4
# 4Vb5Y6RQztThqqqFre24wL       285962               4

# %%
final_df.describe()
# Out:
#          popularity  danceability        energy           key      loudness  \
# count  61116.000000  61116.000000  61116.000000  61116.000000  61116.000000
# mean      42.683536      0.562745      0.592023      5.241361     -9.759729
# std       20.443069      0.168019      0.243643      3.531235      4.644889
# min        0.000000      0.000000      0.000020      0.000000    -47.070000
# 25%       33.000000      0.449000      0.416000      2.000000    -12.224000
# 50%       44.000000      0.570000      0.609000      5.000000     -8.968000
# 75%       57.000000      0.684000      0.793000      8.000000     -6.430000
# max      100.000000      0.988000      1.000000     11.000000      3.744000
#
#                mode   speechiness  acousticness  instrumentalness  \
# count  61116.000000  61116.000000  61116.000000      61116.000000
# mean       0.700373      0.072762      0.328216          0.127186
# std        0.458098      0.084394      0.320412          0.276436
# min        0.000000      0.000000      0.000000          0.000000
# 25%        0.000000      0.033300      0.030700          0.000000
# 50%        1.000000      0.043000      0.216000          0.000106
# 75%        1.000000      0.068200      0.600000          0.027025
# max        1.000000      0.961000      0.996000          1.000000
#
#            liveness       valence        tempo   duration_ms  time_signature
# count  61116.000000  61116.000000  61116.00000  6.111600e+04    61116.000000
# mean       0.202740      0.556389    120.58324  2.362429e+05        3.905622
# std        0.177193      0.257077     29.00575  1.395302e+05        0.385231
# min        0.000000      0.000000      0.00000  1.200000e+04        0.000000
# 25%        0.093100      0.351000     98.03300  1.762270e+05        4.000000
# 50%        0.130000      0.569000    119.86500  2.197070e+05        4.000000
# 75%        0.261000      0.773000    137.81125  2.708670e+05        4.000000
# max        0.997000      0.994000    243.37200  4.800118e+06        5.000000

# %%
final_df.dtypes
# Out:
# track_name           object
# artist_name          object
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# dtype: object

# %% [markdown]
# key is a reserved keyword in mysql, either change the name or surround it with backticks \`key\`

# %%
start = datetime.now()
print("start = ", start)
try:
    mydb = mysql.connector.connect(
        host=os.environ['MYSQL_SPOTIFY_HOST'],
        user=os.environ['MYSQL_SPOTIFY_USER'],
        password=os.environ['MYSQL_SPOTIFY_PW']
    )

    mycursor = mydb.cursor()

    mycursor.execute("CREATE DATABASE IF NOT EXISTS wilts_songs;")

    mydb = mysql.connector.connect(
        host=os.environ['MYSQL_SPOTIFY_HOST'],
        user=os.environ['MYSQL_SPOTIFY_USER'],
        password=os.environ['MYSQL_SPOTIFY_PW'],
        database="wilts_songs"
    )

    mycursor = mydb.cursor()
    mycursor.execute("""DROP TABLE IF EXISTS songs_full""")
    mycursor.execute("""CREATE TABLE IF NOT EXISTS songs_full (
    id VARCHAR(55) NOT NULL PRIMARY KEY,
    track_name VARCHAR(250),
    artist_name VARCHAR(150),
    popularity TINYINT,
    duration_ms INT,
    danceability FLOAT,
    time_signature TINYINT,
    energy FLOAT,
    song_key TINYINT,
    loudness FLOAT,
    mode TINYINT,
    speechiness FLOAT,
    acousticness FLOAT,
    instrumentalness FLOAT,
    liveness FLOAT,
    valence FLOAT,
    tempo FLOAT
    ) ENGINE=InnoDB;""")

    mysql_insert_query = """INSERT INTO songs_full (id, track_name, artist_name, popularity, duration_ms,
        danceability, time_signature, energy, song_key, loudness, mode, speechiness, acousticness,
        instrumentalness, liveness, valence, tempo)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""

    selected_cols = ['track_name', 'artist_name', 'popularity', 'duration_ms',
        'danceability', 'time_signature', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
        'instrumentalness', 'liveness', 'valence', 'tempo']

    records = [record.item() for record in final_df[selected_cols].to_records()]
    mycursor.executemany(mysql_insert_query, records)

    mydb.commit()
except mysql.connector.Error as error:
    print("Failed to insert into MySQL table {}".format(error))

finally:
    if mydb.is_connected():
        mycursor.close()
        mydb.close()
        print("MySQL connection is closed")
    end = datetime.now()
    print("finish = ", end)
    print("duration = ", (end-start).total_seconds())
#  EVENTUELLEMENT AJOUTER DECONNEXION DB ET CURSEUR ET TRY ETC
#     try:
#         connection = mysql.connector.connect(host='localhost',
#                                              database='Electronics',
#                                              user='pynative',
#                                              password='pynative@#29')
#         cursor = connection.cursor()
#         mySql_insert_query = """INSERT INTO Laptop (Id, Name, Price, Purchase_date) 
#                                 VALUES (%s, %s, %s, %s) """

#         record = (id, name, price, purchase_date)
#         cursor.execute(mySql_insert_query, record)
#         connection.commit()
#         print("Record inserted successfully into Laptop table")

#     except mysql.connector.Error as error:
#         print("Failed to insert into MySQL table {}".format(error))

#     finally:
#         if connection.is_connected():
#             cursor.close()
#             connection.close()
#             print("MySQL connection is closed")
# Out:
# start =  2022-07-04 11:26:02.084367
# MySQL connection is closed
# finish =  2022-07-04 11:26:05.362779
# duration =  3.278412
